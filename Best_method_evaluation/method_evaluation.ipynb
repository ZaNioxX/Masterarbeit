# %%
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Pfizer

# %%
rrr_chi2_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/rrr_chi2_Pfizer.npy', allow_pickle=True)
prr_chi2_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/prr_chi2_Pfizer.npy', allow_pickle=True)
ror_chi2_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/ror_chi2_Pfizer.npy', allow_pickle=True)
ic_chi2_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/ic_chi2_Pfizer.npy', allow_pickle=True)

rrr_ci_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/rrr_ci_Pfizer.npy', allow_pickle=True)
prr_ci_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/prr_ci_Pfizer.npy', allow_pickle=True)
ror_ci_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/ror_ci_Pfizer.npy', allow_pickle=True)
ic_ci_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/ic_ci_Pfizer.npy', allow_pickle=True)

y_true_Pfizer = np.load('../Array_Generation/All_data/Arrays_Pfizer/y_true_Pfizer.npy', allow_pickle=True)

# %%
len(y_true)
# Out:
# 20428

# %%
#Accuracy
rrr_chi2_accuracy_Pfizer = accuracy_score(y_true_Pfizer, rrr_chi2_Pfizer)
rrr_ci_accuracy_Pfizer = accuracy_score(y_true_Pfizer, rrr_ci_Pfizer)

prr_chi2_accuracy_Pfizer = accuracy_score(y_true_Pfizer, prr_chi2_Pfizer)
prr_ci_accuracy_Pfizer = accuracy_score(y_true_Pfizer, prr_ci_Pfizer)

ror_chi2_accuracy_Pfizer = accuracy_score(y_true_Pfizer, ror_chi2_Pfizer)
ror_ci_accuracy_Pfizer = accuracy_score(y_true_Pfizer, ror_ci_Pfizer)

ic_chi2_accuracy_Pfizer = accuracy_score(y_true_Pfizer, ic_chi2_Pfizer)
ic_ci_accuracy_Pfizer = accuracy_score(y_true_Pfizer, ic_ci_Pfizer)

#Precision
rrr_chi2_precision_Pfizer = precision_score(y_true_Pfizer, rrr_chi2_Pfizer)
rrr_ci_precision_Pfizer = precision_score(y_true_Pfizer, rrr_ci_Pfizer)

prr_chi2_precision_Pfizer = precision_score(y_true_Pfizer, prr_chi2_Pfizer)
prr_ci_precision_Pfizer = precision_score(y_true_Pfizer, prr_ci_Pfizer)

ror_chi2_precision_Pfizer = precision_score(y_true_Pfizer, ror_chi2_Pfizer)
ror_ci_precision_Pfizer = precision_score(y_true_Pfizer, ror_ci_Pfizer)

ic_chi2_precision_Pfizer = precision_score(y_true_Pfizer, ic_chi2_Pfizer)
ic_ci_precision_Pfizer = precision_score(y_true_Pfizer, ic_ci_Pfizer)

#F1 Score
rrr_chi2_f1_Pfizer = f1_score(y_true_Pfizer, rrr_chi2_Pfizer)
rrr_ci_f1_Pfizer = f1_score(y_true_Pfizer, rrr_ci_Pfizer)

prr_chi2_f1_Pfizer = f1_score(y_true_Pfizer, prr_chi2_Pfizer)
prr_ci_f1_Pfizer = f1_score(y_true_Pfizer, prr_ci_Pfizer)

ror_chi2_f1_Pfizer = f1_score(y_true_Pfizer, ror_chi2_Pfizer)
ror_ci_f1_Pfizer = f1_score(y_true_Pfizer, ror_ci_Pfizer)

ic_chi2_f1_Pfizer = f1_score(y_true_Pfizer, ic_chi2_Pfizer)
ic_ci_f1_Pfizer = f1_score(y_true_Pfizer, ic_ci_Pfizer)

#Recall
rrr_chi2_recall_Pfizer = recall_score(y_true_Pfizer, rrr_chi2_Pfizer)
rrr_ci_recall_Pfizer = recall_score(y_true_Pfizer, rrr_ci_Pfizer)

prr_chi2_recall_Pfizer = recall_score(y_true_Pfizer, prr_chi2_Pfizer)
prr_ci_recall_Pfizer = recall_score(y_true_Pfizer, prr_ci_Pfizer)

ror_chi2_recall_Pfizer = recall_score(y_true_Pfizer, ror_chi2_Pfizer)
ror_ci_recall_Pfizer = recall_score(y_true_Pfizer, ror_ci_Pfizer)

ic_chi2_recall_Pfizer = recall_score(y_true_Pfizer, ic_chi2_Pfizer)
ic_ci_recall_Pfizer = recall_score(y_true_Pfizer, ic_ci_Pfizer)

#Confusion matrix
rrr_chi2_Pfizer_cm = confusion_matrix(y_true_Pfizer, rrr_chi2_Pfizer)
rrr_ci_Pfizer_cm = confusion_matrix(y_true_Pfizer, rrr_ci_Pfizer)

prr_chi2_Pfizer_cm = confusion_matrix(y_true_Pfizer, prr_chi2_Pfizer)
prr_ci_Pfizer_cm = confusion_matrix(y_true_Pfizer, prr_ci_Pfizer)

ror_chi2_Pfizer_cm = confusion_matrix(y_true_Pfizer, ror_chi2_Pfizer)
ror_ci_Pfizer_cm = confusion_matrix(y_true_Pfizer, ror_ci_Pfizer)

ic_chi2_Pfizer_cm = confusion_matrix(y_true_Pfizer, ic_chi2_Pfizer)
ic_ci_Pfizer_cm = confusion_matrix(y_true_Pfizer, ic_ci_Pfizer)

# %%
# Data
methods = ['RRR', 'PRR', 'ROR', 'IC']
chi2_accuracies = [rrr_chi2_accuracy_Pfizer, prr_chi2_accuracy_Pfizer, ror_chi2_accuracy_Pfizer, ic_chi2_accuracy_Pfizer]
ci_accuracies = [rrr_ci_accuracy_Pfizer, prr_ci_accuracy_Pfizer, ror_ci_accuracy_Pfizer, ic_ci_accuracy_Pfizer]

# Plotting
x = np.arange(len(methods))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, chi2_accuracies, width, label='Chi2')
bars2 = ax.bar(x + width/2, ci_accuracies, width, label='CI')

ax.set_ylim(0, 1.2)
ax.yaxis.set_visible(False)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Accuracy')
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.legend()

# Function to add a value label on each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', rotation=90)

add_labels(bars1)
add_labels(bars2)

plt.show()

# %%
# Data
methods = ['RRR', 'PRR', 'ROR', 'IC']
chi2_precisions = [rrr_chi2_precision_Pfizer, prr_chi2_precision_Pfizer, ror_chi2_precision_Pfizer, ic_chi2_precision_Pfizer]
ci_precisions = [rrr_ci_precision_Pfizer, prr_ci_precision_Pfizer, ror_ci_precision_Pfizer, ic_ci_precision_Pfizer]

# Plotting
x = np.arange(len(methods))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, chi2_precisions, width, label='Chi2')
bars2 = ax.bar(x + width/2, ci_precisions, width, label='CI')

ax.set_ylim(0, 1.2)
ax.yaxis.set_visible(False)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Precision')
ax.set_title('Precision')
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.legend()

# Function to add a value label on each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', rotation=90)

add_labels(bars1)
add_labels(bars2)

plt.show()

# %%
# Data
methods = ['RRR', 'PRR', 'ROR', 'IC']
chi2_recalls = [rrr_chi2_recall_Pfizer, prr_chi2_recall_Pfizer, ror_chi2_recall_Pfizer, ic_chi2_recall_Pfizer]
ci_recalls = [rrr_ci_recall_Pfizer, prr_ci_recall_Pfizer, ror_ci_recall_Pfizer, ic_ci_recall_Pfizer]

# Plotting
x = np.arange(len(methods))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, chi2_recalls, width, label='Chi2')
bars2 = ax.bar(x + width/2, ci_recalls, width, label='CI')

ax.set_ylim(0, 1.2)
ax.yaxis.set_visible(False)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Recall')
ax.set_title('Recall')
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.legend()

# Function to add a value label on each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', rotation=90)

add_labels(bars1)
add_labels(bars2)

plt.show()

# %%
# Data
methods = ['RRR', 'PRR', 'ROR', 'IC']
chi2_f1s = [rrr_chi2_f1_Pfizer, prr_chi2_f1_Pfizer, ror_chi2_f1_Pfizer, ic_chi2_f1_Pfizer]
ci_f1s = [rrr_ci_f1_Pfizer, prr_ci_f1_Pfizer, ror_ci_f1_Pfizer, ic_ci_f1_Pfizer]

# Plotting
x = np.arange(len(methods))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
bars1 = ax.bar(x - width/2, chi2_f1s, width, label='Chi2')
bars2 = ax.bar(x + width/2, ci_f1s, width, label='CI')

ax.set_ylim(0, 1.2)
ax.yaxis.set_visible(False)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('F1')
ax.set_title('F1 Score')
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.legend()

# Function to add a value label on each bar
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.4f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', rotation=90)

add_labels(bars1)
add_labels(bars2)

plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))


# Plotting function for subplots
def plot_metric_subplot(ax, metric_name, chi2_values, ci_values):
    x = np.arange(len(methods))  # the label locations
    width = 0.35  # the width of the bars

    bars1 = ax.bar(x - width/2, chi2_values, width, label='Chi2')
    bars2 = ax.bar(x + width/2, ci_values, width, label='CI')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(f'{metric_name} Pfizer')
    ax.set_xticks(x)
    ax.set_xticklabels(methods)
    ax.legend()

    # Setting the y-axis limit to 1.2 and removing the y-axis annotation
    ax.set_ylim(0, 1.2)
    ax.yaxis.set_visible(False)

    # Function to add a value label on each bar, rotated 90 degrees
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.4f}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom',
                        rotation=90)

    add_labels(bars1)
    add_labels(bars2)

# Plotting accuracy, precision, recall, and f1-score in subplots
plot_metric_subplot(axs[0, 0], 'Accuracy', chi2_accuracies, ci_accuracies)
plot_metric_subplot(axs[0, 1], 'Precision', chi2_precisions, ci_precisions)
plot_metric_subplot(axs[1, 0], 'Recall', chi2_recalls, ci_recalls)
plot_metric_subplot(axs[1, 1], 'F1-score', chi2_f1s, ci_f1s)

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/method_evaluation_Pfizer_all.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting function for confusion matrix
def plot_confusion_matrix_subplot(ax, cm, title):
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax, cbar=False)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.set_title(title)
    
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

# Plot confusion matrices in subplots
plot_confusion_matrix_subplot(axs[0, 0], rrr_chi2_Pfizer_cm, 'rrr (chi2) Pfizer')
plot_confusion_matrix_subplot(axs[1, 0], rrr_ci_Pfizer_cm, 'rrr (ci) Pfizer')

plot_confusion_matrix_subplot(axs[0, 1], prr_chi2_Pfizer_cm, 'prr (chi2) Pfizer')
plot_confusion_matrix_subplot(axs[1, 1], prr_ci_Pfizer_cm, 'prr (ci) Pfizer')

plot_confusion_matrix_subplot(axs[0, 2], ror_chi2_Pfizer_cm, 'ror (chi2) Pfizer')
plot_confusion_matrix_subplot(axs[1, 2], ror_ci_Pfizer_cm, 'ror (ci) Pfizer')

plot_confusion_matrix_subplot(axs[0, 3], ic_chi2_Pfizer_cm, 'ic (chi2) Pfizer')
plot_confusion_matrix_subplot(axs[1, 3], ic_ci_Pfizer_cm, 'ic (ci) Pfizer')

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/confusion_matrices_Pfizer_all.eps', format='eps')
plt.show()

# %% [markdown]
# ### Moderna

# %%
rrr_chi2_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/rrr_chi2_Moderna.npy', allow_pickle=True)
prr_chi2_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/prr_chi2_Moderna.npy', allow_pickle=True)
ror_chi2_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/ror_chi2_Moderna.npy', allow_pickle=True)
ic_chi2_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/ic_chi2_Moderna.npy', allow_pickle=True)

rrr_ci_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/rrr_ci_Moderna.npy', allow_pickle=True)
prr_ci_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/prr_ci_Moderna.npy', allow_pickle=True)
ror_ci_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/ror_ci_Moderna.npy', allow_pickle=True)
ic_ci_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/ic_ci_Moderna.npy', allow_pickle=True)

y_true_Moderna = np.load('../Array_Generation/All_data/Arrays_Moderna/y_true_Moderna.npy', allow_pickle=True)

# %%
#Accuracy
rrr_chi2_accuracy_Moderna = accuracy_score(y_true_Moderna, rrr_chi2_Moderna)
rrr_ci_accuracy_Moderna = accuracy_score(y_true_Moderna, rrr_ci_Moderna)

prr_chi2_accuracy_Moderna = accuracy_score(y_true_Moderna, prr_chi2_Moderna)
prr_ci_accuracy_Moderna = accuracy_score(y_true_Moderna, prr_ci_Moderna)

ror_chi2_accuracy_Moderna = accuracy_score(y_true_Moderna, ror_chi2_Moderna)
ror_ci_accuracy_Moderna = accuracy_score(y_true_Moderna, ror_ci_Moderna)

ic_chi2_accuracy_Moderna = accuracy_score(y_true_Moderna, ic_chi2_Moderna)
ic_ci_accuracy_Moderna = accuracy_score(y_true_Moderna, ic_ci_Moderna)

#Precision
rrr_chi2_precision_Moderna = precision_score(y_true_Moderna, rrr_chi2_Moderna)
rrr_ci_precision_Moderna = precision_score(y_true_Moderna, rrr_ci_Moderna)

prr_chi2_precision_Moderna = precision_score(y_true_Moderna, prr_chi2_Moderna)
prr_ci_precision_Moderna = precision_score(y_true_Moderna, prr_ci_Moderna)

ror_chi2_precision_Moderna = precision_score(y_true_Moderna, ror_chi2_Moderna)
ror_ci_precision_Moderna = precision_score(y_true_Moderna, ror_ci_Moderna)

ic_chi2_precision_Moderna = precision_score(y_true_Moderna, ic_chi2_Moderna)
ic_ci_precision_Moderna = precision_score(y_true_Moderna, ic_ci_Moderna)

#F1 Score
rrr_chi2_f1_Moderna = f1_score(y_true_Moderna, rrr_chi2_Moderna)
rrr_ci_f1_Moderna = f1_score(y_true_Moderna, rrr_ci_Moderna)

prr_chi2_f1_Moderna = f1_score(y_true_Moderna, prr_chi2_Moderna)
prr_ci_f1_Moderna = f1_score(y_true_Moderna, prr_ci_Moderna)

ror_chi2_f1_Moderna = f1_score(y_true_Moderna, ror_chi2_Moderna)
ror_ci_f1_Moderna = f1_score(y_true_Moderna, ror_ci_Moderna)

ic_chi2_f1_Moderna = f1_score(y_true_Moderna, ic_chi2_Moderna)
ic_ci_f1_Moderna = f1_score(y_true_Moderna, ic_ci_Moderna)

#Recall
rrr_chi2_recall_Moderna = recall_score(y_true_Moderna, rrr_chi2_Moderna)
rrr_ci_recall_Moderna = recall_score(y_true_Moderna, rrr_ci_Moderna)

prr_chi2_recall_Moderna = recall_score(y_true_Moderna, prr_chi2_Moderna)
prr_ci_recall_Moderna = recall_score(y_true_Moderna, prr_ci_Moderna)

ror_chi2_recall_Moderna = recall_score(y_true_Moderna, ror_chi2_Moderna)
ror_ci_recall_Moderna = recall_score(y_true_Moderna, ror_ci_Moderna)

ic_chi2_recall_Moderna = recall_score(y_true_Moderna, ic_chi2_Moderna)
ic_ci_recall_Moderna = recall_score(y_true_Moderna, ic_ci_Moderna)

#Confusion matrix
rrr_chi2_Moderna_cm = confusion_matrix(y_true_Moderna, rrr_chi2_Moderna)
rrr_ci_Moderna_cm = confusion_matrix(y_true_Moderna, rrr_ci_Moderna)

prr_chi2_Moderna_cm = confusion_matrix(y_true_Moderna, prr_chi2_Moderna)
prr_ci_Moderna_cm = confusion_matrix(y_true_Moderna, prr_ci_Moderna)

ror_chi2_Moderna_cm = confusion_matrix(y_true_Moderna, ror_chi2_Moderna)
ror_ci_Moderna_cm = confusion_matrix(y_true_Moderna, ror_ci_Moderna)

ic_chi2_Moderna_cm = confusion_matrix(y_true_Moderna, ic_chi2_Moderna)
ic_ci_Moderna_cm = confusion_matrix(y_true_Moderna, ic_ci_Moderna)

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
methods = ['RRR', 'PRR', 'ROR', 'IC']

chi2_accuracies = [rrr_chi2_accuracy_Moderna, prr_chi2_accuracy_Moderna, ror_chi2_accuracy_Moderna, ic_chi2_accuracy_Moderna]
ci_accuracies = [rrr_ci_accuracy_Moderna, prr_ci_accuracy_Moderna, ror_ci_accuracy_Moderna, ic_ci_accuracy_Moderna]

chi2_precisions = [rrr_chi2_precision_Moderna, prr_chi2_precision_Moderna, ror_chi2_precision_Moderna, ic_chi2_precision_Moderna]
ci_precisions = [rrr_ci_precision_Moderna, prr_ci_precision_Moderna, ror_ci_precision_Moderna, ic_ci_precision_Moderna]

chi2_recalls = [rrr_chi2_recall_Moderna, prr_chi2_recall_Moderna, ror_chi2_recall_Moderna, ic_chi2_recall_Moderna]
ci_recalls = [rrr_ci_recall_Moderna, prr_ci_recall_Moderna, ror_ci_recall_Moderna, ic_ci_recall_Moderna]

chi2_f1s = [rrr_chi2_f1_Moderna, prr_chi2_f1_Moderna, ror_chi2_f1_Moderna, ic_chi2_f1_Moderna]
ci_f1s = [rrr_ci_f1_Moderna, prr_ci_f1_Moderna, ror_ci_f1_Moderna, ic_ci_f1_Moderna]
# Plotting function for subplots
def plot_metric_subplot(ax, metric_name, chi2_values, ci_values):
    x = np.arange(len(methods))  # the label locations
    width = 0.35  # the width of the bars

    bars1 = ax.bar(x - width/2, chi2_values, width, label='Chi2')
    bars2 = ax.bar(x + width/2, ci_values, width, label='CI')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(f'{metric_name} Moderna')
    ax.set_xticks(x)
    ax.set_xticklabels(methods)
    ax.legend()

    # Setting the y-axis limit to 1.2 and removing the y-axis annotation
    ax.set_ylim(0, 1.2)
    ax.yaxis.set_visible(False)

    # Function to add a value label on each bar, rotated 90 degrees
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.4f}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom',
                        rotation=90)

    add_labels(bars1)
    add_labels(bars2)

# Plotting accuracy, precision, recall, and f1-score in subplots
plot_metric_subplot(axs[0, 0], 'Accuracy', chi2_accuracies, ci_accuracies)
plot_metric_subplot(axs[0, 1], 'Precision', chi2_precisions, ci_precisions)
plot_metric_subplot(axs[1, 0], 'Recall', chi2_recalls, ci_recalls)
plot_metric_subplot(axs[1, 1], 'F1-score', chi2_f1s, ci_f1s)


plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/method_evaluation_Moderna_all.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting function for confusion matrix
def plot_confusion_matrix_subplot(ax, cm, title):
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax, cbar=False)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.set_title(title)
    
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

# Plot confusion matrices in subplots
plot_confusion_matrix_subplot(axs[0, 0], rrr_chi2_Moderna_cm, 'rrr (chi2) Moderna')
plot_confusion_matrix_subplot(axs[1, 0], rrr_ci_Moderna_cm, 'rrr (ci) Moderna')

plot_confusion_matrix_subplot(axs[0, 1], prr_chi2_Moderna_cm, 'prr (chi2) Moderna')
plot_confusion_matrix_subplot(axs[1, 1], prr_ci_Moderna_cm, 'prr (ci) Moderna')

plot_confusion_matrix_subplot(axs[0, 2], ror_chi2_Moderna_cm, 'ror (chi2) Moderna')
plot_confusion_matrix_subplot(axs[1, 2], ror_ci_Moderna_cm, 'ror (ci) Moderna')

plot_confusion_matrix_subplot(axs[0, 3], ic_chi2_Moderna_cm, 'ic (chi2) Moderna')
plot_confusion_matrix_subplot(axs[1, 3], ic_ci_Moderna_cm, 'ic (ci) Moderna')

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/confusion_matrices_Moderna_all.eps', format='eps')
plt.show()

# %% [markdown]
# ### Janssen

# %%
rrr_chi2_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/rrr_chi2_Janssen.npy', allow_pickle=True)
prr_chi2_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/prr_chi2_Janssen.npy', allow_pickle=True)
ror_chi2_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/ror_chi2_Janssen.npy', allow_pickle=True)
ic_chi2_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/ic_chi2_Janssen.npy', allow_pickle=True)

rrr_ci_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/rrr_ci_Janssen.npy', allow_pickle=True)
prr_ci_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/prr_ci_Janssen.npy', allow_pickle=True)
ror_ci_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/ror_ci_Janssen.npy', allow_pickle=True)
ic_ci_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/ic_ci_Janssen.npy', allow_pickle=True)

y_true_Janssen = np.load('../Array_Generation/All_data/Arrays_Janssen/y_true_Janssen.npy', allow_pickle=True)

# %%
#Accuracy
rrr_chi2_accuracy_Janssen = accuracy_score(y_true_Janssen, rrr_chi2_Janssen)
rrr_ci_accuracy_Janssen = accuracy_score(y_true_Janssen, rrr_ci_Janssen)

prr_chi2_accuracy_Janssen = accuracy_score(y_true_Janssen, prr_chi2_Janssen)
prr_ci_accuracy_Janssen = accuracy_score(y_true_Janssen, prr_ci_Janssen)

ror_chi2_accuracy_Janssen = accuracy_score(y_true_Janssen, ror_chi2_Janssen)
ror_ci_accuracy_Janssen = accuracy_score(y_true_Janssen, ror_ci_Janssen)

ic_chi2_accuracy_Janssen = accuracy_score(y_true_Janssen, ic_chi2_Janssen)
ic_ci_accuracy_Janssen = accuracy_score(y_true_Janssen, ic_ci_Janssen)

#Precision
rrr_chi2_precision_Janssen = precision_score(y_true_Janssen, rrr_chi2_Janssen)
rrr_ci_precision_Janssen = precision_score(y_true_Janssen, rrr_ci_Janssen)

prr_chi2_precision_Janssen = precision_score(y_true_Janssen, prr_chi2_Janssen)
prr_ci_precision_Janssen = precision_score(y_true_Janssen, prr_ci_Janssen)

ror_chi2_precision_Janssen = precision_score(y_true_Janssen, ror_chi2_Janssen)
ror_ci_precision_Janssen = precision_score(y_true_Janssen, ror_ci_Janssen)

ic_chi2_precision_Janssen = precision_score(y_true_Janssen, ic_chi2_Janssen)
ic_ci_precision_Janssen = precision_score(y_true_Janssen, ic_ci_Janssen)

#F1 Score
rrr_chi2_f1_Janssen = f1_score(y_true_Janssen, rrr_chi2_Janssen)
rrr_ci_f1_Janssen = f1_score(y_true_Janssen, rrr_ci_Janssen)

prr_chi2_f1_Janssen = f1_score(y_true_Janssen, prr_chi2_Janssen)
prr_ci_f1_Janssen = f1_score(y_true_Janssen, prr_ci_Janssen)

ror_chi2_f1_Janssen = f1_score(y_true_Janssen, ror_chi2_Janssen)
ror_ci_f1_Janssen = f1_score(y_true_Janssen, ror_ci_Janssen)

ic_chi2_f1_Janssen = f1_score(y_true_Janssen, ic_chi2_Janssen)
ic_ci_f1_Janssen = f1_score(y_true_Janssen, ic_ci_Janssen)

#Recall
rrr_chi2_recall_Janssen = recall_score(y_true_Janssen, rrr_chi2_Janssen)
rrr_ci_recall_Janssen = recall_score(y_true_Janssen, rrr_ci_Janssen)

prr_chi2_recall_Janssen = recall_score(y_true_Janssen, prr_chi2_Janssen)
prr_ci_recall_Janssen = recall_score(y_true_Janssen, prr_ci_Janssen)

ror_chi2_recall_Janssen = recall_score(y_true_Janssen, ror_chi2_Janssen)
ror_ci_recall_Janssen = recall_score(y_true_Janssen, ror_ci_Janssen)

ic_chi2_recall_Janssen = recall_score(y_true_Janssen, ic_chi2_Janssen)
ic_ci_recall_Janssen = recall_score(y_true_Janssen, ic_ci_Janssen)

#Confusion matrix
rrr_chi2_Janssen_cm = confusion_matrix(y_true_Janssen, rrr_chi2_Janssen)
rrr_ci_Janssen_cm = confusion_matrix(y_true_Janssen, rrr_ci_Janssen)

prr_chi2_Janssen_cm = confusion_matrix(y_true_Janssen, prr_chi2_Janssen)
prr_ci_Janssen_cm = confusion_matrix(y_true_Janssen, prr_ci_Janssen)

ror_chi2_Janssen_cm = confusion_matrix(y_true_Janssen, ror_chi2_Janssen)
ror_ci_Janssen_cm = confusion_matrix(y_true_Janssen, ror_ci_Janssen)

ic_chi2_Janssen_cm = confusion_matrix(y_true_Janssen, ic_chi2_Janssen)
ic_ci_Janssen_cm = confusion_matrix(y_true_Janssen, ic_ci_Janssen)

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
methods = ['RRR', 'PRR', 'ROR', 'IC']

chi2_accuracies = [rrr_chi2_accuracy_Janssen, prr_chi2_accuracy_Janssen, ror_chi2_accuracy_Janssen, ic_chi2_accuracy_Janssen]
ci_accuracies = [rrr_ci_accuracy_Janssen, prr_ci_accuracy_Janssen, ror_ci_accuracy_Janssen, ic_ci_accuracy_Janssen]

chi2_precisions = [rrr_chi2_precision_Janssen, prr_chi2_precision_Janssen, ror_chi2_precision_Janssen, ic_chi2_precision_Janssen]
ci_precisions = [rrr_ci_precision_Janssen, prr_ci_precision_Janssen, ror_ci_precision_Janssen, ic_ci_precision_Janssen]

chi2_recalls = [rrr_chi2_recall_Janssen, prr_chi2_recall_Janssen, ror_chi2_recall_Janssen, ic_chi2_recall_Janssen]
ci_recalls = [rrr_ci_recall_Janssen, prr_ci_recall_Janssen, ror_ci_recall_Janssen, ic_ci_recall_Janssen]

chi2_f1s = [rrr_chi2_f1_Janssen, prr_chi2_f1_Janssen, ror_chi2_f1_Janssen, ic_chi2_f1_Janssen]
ci_f1s = [rrr_ci_f1_Janssen, prr_ci_f1_Janssen, ror_ci_f1_Janssen, ic_ci_f1_Janssen]
# Plotting function for subplots
def plot_metric_subplot(ax, metric_name, chi2_values, ci_values):
    x = np.arange(len(methods))  # the label locations
    width = 0.35  # the width of the bars

    bars1 = ax.bar(x - width/2, chi2_values, width, label='Chi2')
    bars2 = ax.bar(x + width/2, ci_values, width, label='CI')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(f'{metric_name} Janssen')
    ax.set_xticks(x)
    ax.set_xticklabels(methods)
    ax.legend()

    # Setting the y-axis limit to 1.2 and removing the y-axis annotation
    ax.set_ylim(0, 1.2)
    ax.yaxis.set_visible(False)

    # Function to add a value label on each bar, rotated 90 degrees
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.4f}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom',
                        rotation=90)

    add_labels(bars1)
    add_labels(bars2)

# Plotting accuracy, precision, recall, and f1-score in subplots
plot_metric_subplot(axs[0, 0], 'Accuracy', chi2_accuracies, ci_accuracies)
plot_metric_subplot(axs[0, 1], 'Precision', chi2_precisions, ci_precisions)
plot_metric_subplot(axs[1, 0], 'Recall', chi2_recalls, ci_recalls)
plot_metric_subplot(axs[1, 1], 'F1-score', chi2_f1s, ci_f1s)

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/method_evaluation_Janssen_all.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting function for confusion matrix
def plot_confusion_matrix_subplot(ax, cm, title):
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax, cbar=False)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.set_title(title)
    
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

# Plot confusion matrices in subplots
plot_confusion_matrix_subplot(axs[0, 0], rrr_chi2_Janssen_cm, 'rrr (chi2) Janssen')
plot_confusion_matrix_subplot(axs[1, 0], rrr_ci_Janssen_cm, 'rrr (ci) Janssen')

plot_confusion_matrix_subplot(axs[0, 1], prr_chi2_Janssen_cm, 'prr (chi2) Janssen')
plot_confusion_matrix_subplot(axs[1, 1], prr_ci_Janssen_cm, 'prr (ci) Moderna')

plot_confusion_matrix_subplot(axs[0, 2], ror_chi2_Janssen_cm, 'ror (chi2) Janssen')
plot_confusion_matrix_subplot(axs[1, 2], ror_ci_Janssen_cm, 'ror (ci) Janssen')

plot_confusion_matrix_subplot(axs[0, 3], ic_chi2_Janssen_cm, 'ic (chi2) Janssen')
plot_confusion_matrix_subplot(axs[1, 3], ic_ci_Janssen_cm, 'ic (ci) Janssen')

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/confusion_matrices_Janssen_all.eps', format='eps')
plt.show()

# %% [markdown]
# ### Novavax

# %%
rrr_chi2_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/rrr_chi2_Novavax.npy', allow_pickle=True)
prr_chi2_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/prr_chi2_Novavax.npy', allow_pickle=True)
ror_chi2_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/ror_chi2_Novavax.npy', allow_pickle=True)
ic_chi2_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/ic_chi2_Novavax.npy', allow_pickle=True)

rrr_ci_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/rrr_ci_Novavax.npy', allow_pickle=True)
prr_ci_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/prr_ci_Novavax.npy', allow_pickle=True)
ror_ci_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/ror_ci_Novavax.npy', allow_pickle=True)
ic_ci_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/ic_ci_Novavax.npy', allow_pickle=True)

y_true_Novavax = np.load('../Array_Generation/All_data/Arrays_Novavax/y_true_Novavax.npy', allow_pickle=True)

# %%
#Accuracy
rrr_chi2_accuracy_Novavax = accuracy_score(y_true_Novavax, rrr_chi2_Novavax)
rrr_ci_accuracy_Novavax = accuracy_score(y_true_Novavax, rrr_ci_Novavax)

prr_chi2_accuracy_Novavax = accuracy_score(y_true_Novavax, prr_chi2_Novavax)
prr_ci_accuracy_Novavax = accuracy_score(y_true_Novavax, prr_ci_Novavax)

ror_chi2_accuracy_Novavax = accuracy_score(y_true_Novavax, ror_chi2_Novavax)
ror_ci_accuracy_Novavax = accuracy_score(y_true_Novavax, ror_ci_Novavax)

ic_chi2_accuracy_Novavax = accuracy_score(y_true_Novavax, ic_chi2_Novavax)
ic_ci_accuracy_Novavax = accuracy_score(y_true_Novavax, ic_ci_Novavax)

#Precision
rrr_chi2_precision_Novavax = precision_score(y_true_Novavax, rrr_chi2_Novavax)
rrr_ci_precision_Novavax = precision_score(y_true_Novavax, rrr_ci_Novavax)

prr_chi2_precision_Novavax = precision_score(y_true_Novavax, prr_chi2_Novavax)
prr_ci_precision_Novavax = precision_score(y_true_Novavax, prr_ci_Novavax)

ror_chi2_precision_Novavax = precision_score(y_true_Novavax, ror_chi2_Novavax)
ror_ci_precision_Novavax = precision_score(y_true_Novavax, ror_ci_Novavax)

ic_chi2_precision_Novavax = precision_score(y_true_Novavax, ic_chi2_Novavax)
ic_ci_precision_Novavax = precision_score(y_true_Novavax, ic_ci_Novavax)

#F1 Score
rrr_chi2_f1_Novavax = f1_score(y_true_Novavax, rrr_chi2_Novavax)
rrr_ci_f1_Novavax = f1_score(y_true_Novavax, rrr_ci_Novavax)

prr_chi2_f1_Novavax = f1_score(y_true_Novavax, prr_chi2_Novavax)
prr_ci_f1_Novavax = f1_score(y_true_Novavax, prr_ci_Novavax)

ror_chi2_f1_Novavax = f1_score(y_true_Novavax, ror_chi2_Novavax)
ror_ci_f1_Novavax = f1_score(y_true_Novavax, ror_ci_Novavax)

ic_chi2_f1_Novavax = f1_score(y_true_Novavax, ic_chi2_Novavax)
ic_ci_f1_Novavax = f1_score(y_true_Novavax, ic_ci_Novavax)

#Recall
rrr_chi2_recall_Novavax = recall_score(y_true_Novavax, rrr_chi2_Novavax)
rrr_ci_recall_Novavax = recall_score(y_true_Novavax, rrr_ci_Novavax)

prr_chi2_recall_Novavax = recall_score(y_true_Novavax, prr_chi2_Novavax)
prr_ci_recall_Novavax = recall_score(y_true_Novavax, prr_ci_Novavax)

ror_chi2_recall_Novavax = recall_score(y_true_Novavax, ror_chi2_Novavax)
ror_ci_recall_Novavax = recall_score(y_true_Novavax, ror_ci_Novavax)

ic_chi2_recall_Novavax = recall_score(y_true_Novavax, ic_chi2_Novavax)
ic_ci_recall_Novavax = recall_score(y_true_Novavax, ic_ci_Novavax)

#Confusion matrix
rrr_chi2_Novavax_cm = confusion_matrix(y_true_Novavax, rrr_chi2_Novavax)
rrr_ci_Novavax_cm = confusion_matrix(y_true_Novavax, rrr_ci_Novavax)

prr_chi2_Novavax_cm = confusion_matrix(y_true_Novavax, prr_chi2_Novavax)
prr_ci_Novavax_cm = confusion_matrix(y_true_Novavax, prr_ci_Novavax)

ror_chi2_Novavax_cm = confusion_matrix(y_true_Novavax, ror_chi2_Novavax)
ror_ci_Novavax_cm = confusion_matrix(y_true_Novavax, ror_ci_Novavax)

ic_chi2_Novavax_cm = confusion_matrix(y_true_Novavax, ic_chi2_Novavax)
ic_ci_Novavax_cm = confusion_matrix(y_true_Novavax, ic_ci_Novavax)

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 15))
methods = ['RRR', 'PRR', 'ROR', 'IC']

chi2_accuracies = [rrr_chi2_accuracy_Novavax, prr_chi2_accuracy_Novavax, ror_chi2_accuracy_Novavax, ic_chi2_accuracy_Novavax]
ci_accuracies = [rrr_ci_accuracy_Novavax, prr_ci_accuracy_Novavax, ror_ci_accuracy_Novavax, ic_ci_accuracy_Novavax]

chi2_precisions = [rrr_chi2_precision_Novavax, prr_chi2_precision_Novavax, ror_chi2_precision_Novavax, ic_chi2_precision_Novavax]
ci_precisions = [rrr_ci_precision_Novavax, prr_ci_precision_Novavax, ror_ci_precision_Novavax, ic_ci_precision_Novavax]

chi2_recalls = [rrr_chi2_recall_Novavax, prr_chi2_recall_Novavax, ror_chi2_recall_Novavax, ic_chi2_recall_Novavax]
ci_recalls = [rrr_ci_recall_Novavax, prr_ci_recall_Novavax, ror_ci_recall_Novavax, ic_ci_recall_Novavax]

chi2_f1s = [rrr_chi2_f1_Novavax, prr_chi2_f1_Novavax, ror_chi2_f1_Novavax, ic_chi2_f1_Novavax]
ci_f1s = [rrr_ci_f1_Novavax, prr_ci_f1_Novavax, ror_ci_f1_Novavax, ic_ci_f1_Novavax]
# Plotting function for subplots
def plot_metric_subplot(ax, metric_name, chi2_values, ci_values):
    x = np.arange(len(methods))  # the label locations
    width = 0.35  # the width of the bars

    bars1 = ax.bar(x - width/2, chi2_values, width, label='Chi2')
    bars2 = ax.bar(x + width/2, ci_values, width, label='CI')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(f'{metric_name} Novavax')
    ax.set_xticks(x)
    ax.set_xticklabels(methods)
    ax.legend()

    # Setting the y-axis limit to 1.2 and removing the y-axis annotation
    ax.set_ylim(0, 1.2)
    ax.yaxis.set_visible(False)

    # Function to add a value label on each bar, rotated 90 degrees
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.4f}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom',
                        rotation=90)

    add_labels(bars1)
    add_labels(bars2)

# Plotting accuracy, precision, recall, and f1-score in subplots
plot_metric_subplot(axs[0, 0], 'Accuracy', chi2_accuracies, ci_accuracies)
plot_metric_subplot(axs[0, 1], 'Precision', chi2_precisions, ci_precisions)
plot_metric_subplot(axs[1, 0], 'Recall', chi2_recalls, ci_recalls)
plot_metric_subplot(axs[1, 1], 'F1-score', chi2_f1s, ci_f1s)

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/method_evaluation_Novavax_all.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Plotting function for confusion matrix
def plot_confusion_matrix_subplot(ax, cm, title):
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax, cbar=False)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.set_title(title)
    
fig, axs = plt.subplots(2, 4, figsize=(20, 10))

# Plot confusion matrices in subplots
plot_confusion_matrix_subplot(axs[0, 0], rrr_chi2_Novavax_cm, 'rrr (chi2) Novavax')
plot_confusion_matrix_subplot(axs[1, 0], rrr_ci_Novavax_cm, 'rrr (ci) Novavax')

plot_confusion_matrix_subplot(axs[0, 1], prr_chi2_Novavax_cm, 'prr (chi2) Novavax')
plot_confusion_matrix_subplot(axs[1, 1], prr_ci_Novavax_cm, 'prr (ci) Novavax')

plot_confusion_matrix_subplot(axs[0, 2], ror_chi2_Novavax_cm, 'ror (chi2) Novavax')
plot_confusion_matrix_subplot(axs[1, 2], ror_ci_Novavax_cm, 'ror (ci) Novavax')

plot_confusion_matrix_subplot(axs[0, 3], ic_chi2_Novavax_cm, 'ic (chi2) Novavax')
plot_confusion_matrix_subplot(axs[1, 3], ic_ci_Novavax_cm, 'ic (ci) Novavax')

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/confusion_matrices_Novavax_all.eps', format='eps')
plt.show()

# %% [markdown]
# # All

# %%
rrr_chi2 = np.concatenate([rrr_chi2_Pfizer,rrr_chi2_Moderna, rrr_chi2_Janssen,rrr_chi2_Novavax]) 
rrr_ci = np.concatenate([rrr_ci_Pfizer,rrr_ci_Moderna, rrr_ci_Janssen,rrr_ci_Novavax]) 

prr_chi2 = np.concatenate([prr_chi2_Pfizer,prr_chi2_Moderna, prr_chi2_Janssen,prr_chi2_Novavax]) 
prr_ci = np.concatenate([prr_ci_Pfizer,prr_ci_Moderna, prr_ci_Janssen,prr_ci_Novavax]) 

ror_chi2 = np.concatenate([ror_chi2_Pfizer,ror_chi2_Moderna, ror_chi2_Janssen,ror_chi2_Novavax]) 
ror_ci = np.concatenate([ror_ci_Pfizer,ror_ci_Moderna, ror_ci_Janssen,ror_ci_Novavax]) 

ic_chi2 = np.concatenate([ic_chi2_Pfizer, ic_chi2_Moderna, ic_chi2_Janssen, ic_chi2_Novavax]) 
ic_ci = np.concatenate([ic_ci_Pfizer, ic_ci_Moderna, ic_ci_Janssen, ic_ci_Novavax]) 

y_true = np.concatenate([y_true_Pfizer, y_true_Moderna, y_true_Janssen, y_true_Novavax])

# %%
sum(y_true == 0)
# Out:
# 20303

# %%
print(len(ic_chi2))
print(len(ic_ci))
# Out:
# 20428
# 20428

# %%
#Accuracy
rrr_chi2_accuracy = accuracy_score(y_true, rrr_chi2)
rrr_ci_accuracy = accuracy_score(y_true, rrr_ci)

prr_chi2_accuracy = accuracy_score(y_true, prr_chi2)
prr_ci_accuracy = accuracy_score(y_true, prr_ci)

ror_chi2_accuracy = accuracy_score(y_true, ror_chi2)
ror_ci_accuracy = accuracy_score(y_true, ror_ci)

ic_chi2_accuracy = accuracy_score(y_true, ic_chi2)
ic_ci_accuracy = accuracy_score(y_true, ic_ci)

#Precision
rrr_chi2_precision = precision_score(y_true, rrr_chi2)
rrr_ci_precision = precision_score(y_true, rrr_ci)

prr_chi2_precision = precision_score(y_true, prr_chi2)
prr_ci_precision = precision_score(y_true, prr_ci)

ror_chi2_precision = precision_score(y_true, ror_chi2)
ror_ci_precision = precision_score(y_true, ror_ci)

ic_chi2_precision = precision_score(y_true, ic_chi2)
ic_ci_precision = precision_score(y_true, ic_ci)

#F1 Score
rrr_chi2_f1 = f1_score(y_true, rrr_chi2)
rrr_ci_f1 = f1_score(y_true, rrr_ci)

prr_chi2_f1 = f1_score(y_true, prr_chi2)
prr_ci_f1 = f1_score(y_true, prr_ci)

ror_chi2_f1 = f1_score(y_true, ror_chi2)
ror_ci_f1 = f1_score(y_true, ror_ci)

ic_chi2_f1 = f1_score(y_true, ic_chi2)
ic_ci_f1 = f1_score(y_true, ic_ci)

#Recall
rrr_chi2_recall = recall_score(y_true, rrr_chi2)
rrr_ci_recall = recall_score(y_true, rrr_ci)

prr_chi2_recall = recall_score(y_true, prr_chi2)
prr_ci_recall = recall_score(y_true, prr_ci)

ror_chi2_recall = recall_score(y_true, ror_chi2)
ror_ci_recall = recall_score(y_true, ror_ci)

ic_chi2_recall = recall_score(y_true, ic_chi2)
ic_ci_recall = recall_score(y_true, ic_ci)

#Roc Auc
rrr_chi2_rocauc = roc_auc_score(y_true, rrr_chi2)
rrr_ci_rocauc = roc_auc_score(y_true, rrr_ci)

prr_chi2_rocauc = roc_auc_score(y_true, prr_chi2)
prr_ci_rocauc = roc_auc_score(y_true, prr_ci)

ror_chi2_rocauc = roc_auc_score(y_true, ror_chi2)
ror_ci_rocauc = roc_auc_score(y_true, ror_ci)

ic_chi2_rocauc = roc_auc_score(y_true, ic_chi2)
ic_ci_rocauc = roc_auc_score(y_true, ic_ci)

#Confusion matrix
rrr_chi2_cm = confusion_matrix(y_true, rrr_chi2)
rrr_ci_cm = confusion_matrix(y_true, rrr_ci)

prr_chi2_cm = confusion_matrix(y_true, prr_chi2)
prr_ci_cm = confusion_matrix(y_true, prr_ci)

ror_chi2_cm = confusion_matrix(y_true, ror_chi2)
ror_ci_cm = confusion_matrix(y_true, ror_ci)

ic_chi2_cm = confusion_matrix(y_true, ic_chi2)
ic_ci_cm = confusion_matrix(y_true, ic_ci)

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))
methods = ['RRR', 'PRR', 'ROR', 'IC']

chi2_accuracies = [rrr_chi2_accuracy, prr_chi2_accuracy, ror_chi2_accuracy, ic_chi2_accuracy]
ci_accuracies = [rrr_ci_accuracy, prr_ci_accuracy, ror_ci_accuracy, ic_ci_accuracy]

chi2_precisions = [rrr_chi2_precision, prr_chi2_precision, ror_chi2_precision, ic_chi2_precision]
ci_precisions = [rrr_ci_precision, prr_ci_precision, ror_ci_precision, ic_ci_precision]

chi2_recalls = [rrr_chi2_recall, prr_chi2_recall, ror_chi2_recall, ic_chi2_recall]
ci_recalls = [rrr_ci_recall, prr_ci_recall, ror_ci_recall, ic_ci_recall]

chi2_f1s = [rrr_chi2_f1, prr_chi2_f1, ror_chi2_f1, ic_chi2_f1]
ci_f1s = [rrr_ci_f1, prr_ci_f1, ror_ci_f1, ic_ci_f1]

chi2_roc_aucs = [rrr_chi2_rocauc, prr_chi2_rocauc, ror_chi2_rocauc, ic_chi2_rocauc]
ci_roc_aucs = [rrr_ci_rocauc, prr_ci_rocauc, ror_ci_rocauc, ic_ci_rocauc]

# Plotting function for subplots
def plot_metric_subplot(ax, metric_name, chi2_values, ci_values):
    x = np.arange(len(methods))  # the label locations
    width = 0.35  # the width of the bars

    bars1 = ax.bar(x - width/2, chi2_values, width, label='Chi2')
    bars2 = ax.bar(x + width/2, ci_values, width, label='CI')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(f'{metric_name} all manufacturers')
    ax.set_xticks(x)
    ax.set_xticklabels(methods)
    ax.legend()

    # Setting the y-axis limit to 1.2 and removing the y-axis annotation
    ax.set_ylim(0, 1.2)
    ax.yaxis.set_visible(False)

    # Function to add a value label on each bar, rotated 90 degrees
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom'
                        )

    add_labels(bars1)
    add_labels(bars2)

# Plotting accuracy, precision, recall, and f1-score in subplots
plot_metric_subplot(axs[0, 0], 'Accuracy', chi2_accuracies, ci_accuracies)
plot_metric_subplot(axs[0, 1], 'Precision', chi2_precisions, ci_precisions)
plot_metric_subplot(axs[1, 0], 'Recall', chi2_recalls, ci_recalls)
plot_metric_subplot(axs[1, 1], 'F1-score', chi2_f1s, ci_f1s)

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/method_evaluation_all.pdf')
plt.show()

# %%
# Plotting function for confusion matrix
def plot_confusion_matrix_subplot(ax, cm, title):
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax, cbar=False)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    ax.set_title(title)
    
fig, axs = plt.subplots(2, 4, figsize=(10, 6))

# Plot confusion matrices in subplots
plot_confusion_matrix_subplot(axs[0, 0], rrr_chi2_cm, 'rrr (chi2) all')
plot_confusion_matrix_subplot(axs[1, 0], rrr_ci_cm, 'rrr (ci) all')

plot_confusion_matrix_subplot(axs[0, 1], prr_chi2_cm, 'prr (chi2) all')
plot_confusion_matrix_subplot(axs[1, 1], prr_ci_cm, 'prr (ci) all')

plot_confusion_matrix_subplot(axs[0, 2], ror_chi2_cm, 'ror (chi2) all')
plot_confusion_matrix_subplot(axs[1, 2], ror_ci_cm, 'ror (ci) all')

plot_confusion_matrix_subplot(axs[0, 3], ic_chi2_cm, 'ic (chi2) all')
plot_confusion_matrix_subplot(axs[1, 3], ic_ci_cm, 'ic (ci) all')

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/confusion_matrices_all.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(3, 2, figsize=(10, 12))
methods = ['RRR', 'PRR', 'ROR', 'IC']

chi2_accuracies = [rrr_chi2_accuracy, prr_chi2_accuracy, ror_chi2_accuracy, ic_chi2_accuracy]
ci_accuracies = [rrr_ci_accuracy, prr_ci_accuracy, ror_ci_accuracy, ic_ci_accuracy]

chi2_precisions = [rrr_chi2_precision, prr_chi2_precision, ror_chi2_precision, ic_chi2_precision]
ci_precisions = [rrr_ci_precision, prr_ci_precision, ror_ci_precision, ic_ci_precision]

chi2_recalls = [rrr_chi2_recall, prr_chi2_recall, ror_chi2_recall, ic_chi2_recall]
ci_recalls = [rrr_ci_recall, prr_ci_recall, ror_ci_recall, ic_ci_recall]

chi2_f1s = [rrr_chi2_f1, prr_chi2_f1, ror_chi2_f1, ic_chi2_f1]
ci_f1s = [rrr_ci_f1, prr_ci_f1, ror_ci_f1, ic_ci_f1]

chi2_roc_aucs = [rrr_chi2_rocauc, prr_chi2_rocauc, ror_chi2_rocauc, ic_chi2_rocauc]
ci_roc_aucs = [rrr_ci_rocauc, prr_ci_rocauc, ror_ci_rocauc, ic_ci_rocauc]

# Plotting function for subplots
def plot_metric_subplot(ax, metric_name, chi2_values, ci_values):
    x = np.arange(len(methods))  # the label locations
    width = 0.35  # the width of the bars

    bars1 = ax.bar(x - width/2, chi2_values, width, label='Chi2')
    bars2 = ax.bar(x + width/2, ci_values, width, label='CI')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_title(f'{metric_name} all manufacturers')
    ax.set_xticks(x)
    ax.set_xticklabels(methods)
    ax.legend()

    # Setting the y-axis limit to 1.2 and removing the y-axis annotation
    ax.set_ylim(0, 1.2)
    ax.yaxis.set_visible(False)

    # Function to add a value label on each bar, rotated 90 degrees
    def add_labels(bars):
        for bar in bars:
            height = bar.get_height()
            ax.annotate(f'{height:.2f}',
                        xy=(bar.get_x() + bar.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom'
                        )

    add_labels(bars1)
    add_labels(bars2)

# Plotting accuracy, precision, recall, f1-score, and roc-auc in subplots
plot_metric_subplot(axs[0, 0], 'Accuracy', chi2_accuracies, ci_accuracies)
plot_metric_subplot(axs[0, 1], 'Precision', chi2_precisions, ci_precisions)
plot_metric_subplot(axs[1, 0], 'Recall', chi2_recalls, ci_recalls)
plot_metric_subplot(axs[1, 1], 'F1-score', chi2_f1s, ci_f1s)
plot_metric_subplot(axs[2, 0], 'ROC AUC', chi2_roc_aucs, ci_roc_aucs)

# Hide the unused subplot
axs[2, 1].axis('off')

plt.tight_layout()
plt.savefig('/home/sebastian/Documents/Masterarbeit/Plots/Metrics/All_data/method_evaluation_all.pdf')
plt.show()
